# %%
import random

# %%
print('=' * 80)
a, b = map(int,input('고정비용, 가변비용 입력 : ').split())
num = int(input('제품 생산개수 : '));
total = a + (b * num)
print('총 드는 비용 : {}'.format(total))
c = int(input('제품 판매 가격 : '))
sum = c * num
print('최대 얻을 수 있는 이익 : {}만원'.format(sum))
h = total // c + 1

if b >= c:
    print('손익분기점 없음')
else:
    print('손익분기점 : {}개'.format(h))
print('=' * 80)

for i in range(1,1000)[:3]:
    print('{}일째'.format(i))
    r = random.randrange(100)
    s = random.randrange(num)
    price = c * s
    print('방문 고객 수 : {}명'.format(r))
    print('판매 개수 : {}개'.format(s))
    print('판매 이익 : {}만원'.format(price))
    print('{}일째 이익 : {}만원'.format(i, price-total))
    print('=' * 80)
    c += r
    o += s
print('총 고객 수 : {}, 총 제품 판매 수 : {}'.format(c, o))
# Out:
# ...
# 고정비용, 가변비용 입력 : 1000 70
# 제품 생산개수 : 50
# 총 드는 비용 : 4500
# 제품 판매 가격 : 170
# 최대 얻을 수 있는 이익 : 8500만원
# 손익분기점 : 27개
# ...
# 1일째
# 방문 고객 수 : 78명
# 판매 개수 : 26개
# 판매 이익 : 4420만원
# 1일째 이익 : -80만원
# ...
# 2일째
# 방문 고객 수 : 3명
# 판매 개수 : 0개
# 판매 이익 : 0만원
# 2일째 이익 : -4500만원
# ...
# 3일째
# 방문 고객 수 : 27명
# 판매 개수 : 47개
# 판매 이익 : 11797만원
# 3일째 이익 : 7297만원
# ...
# 총 고객 수 : 278, 총 제품 판매 수 : 124

# %%
print('=' * 40)
fc, vc = map(int,input('고정비용, 가변비용 입력 : ').split())
product_num = int(input('제품 생산개수 : '));
cost_total = fc + (vc * product_num)
print('총 드는 비용 : {}'.format(cost_total))

while True:
    price = int(input('제품 판매 가격 : '))
    if price >= vc:
        bep = cost_total // price + 1
        print('손익분기점 : {}개'.format(bep))
        net_profits = (price * product_num) - cost_total
        print('최대 얻을 수 있는 순이익 : {}만원'.format(net_profits))
        break
        
    else:
        print('손익분기점이 없습니다 \n다시 입력하세요')
    
customer = 0
product = 0
netprofit = 0
for j in range(1,10000)[:30]:
    print('=' * 22)
    customers = random.randint(1,100)
    
    while True:
        sell_products = random.randint(1, product_num)
        if sell_products > product_num:
            sell_products = random.randint(1, product_num)
        else:
            break
            
    day_profits = price * sell_products
    day_Netprofits = day_profits - cost_total
    
    print('▶'* 4 + '{}일째'.format(j) + '◀' * 4)
    print('방문 고객 수 : {}명'.format(customers))
    print('제품 판개 개수 : {}개'.format(sell_products))
    print('판매 이익 : {}만원'.format(day_profits))
    print('순이익 : {}만원'.format(day_Netprofits))
    customer += customers
    product += sell_products
    netprofit += day_Netprofits
    
hun_mil = netprofit // 10000
ten_tho = netprofit % 10000

print('=' * 24)
print('총 고객 수 : {}명\n총 제품 판매수 : {}개'.format(customer,product))


if hun_mil == 0:
    print('총 순이익 : {}만원'.format(netprofit))
else:
    print('총 순이익 : {}억 {}만원'.format(hun_mil, ten_tho))
    
if netprofit < -25000:
    print('파산하셨습니다')
# Out:
# ...
# 고정비용, 가변비용 입력 : 1000 70
# 제품 생산개수 : 50
# 총 드는 비용 : 4500
# 제품 판매 가격 : 170
# 손익분기점 : 27개
# 최대 얻을 수 있는 순이익 : 4000만원
# ...
# ▶▶▶▶1일째◀◀◀◀
# 방문 고객 수 : 67명
# 제품 판개 개수 : 46개
# 판매 이익 : 7820만원
# 순이익 : 3320만원
# ...
# ▶▶▶▶2일째◀◀◀◀
# 방문 고객 수 : 54명
# 제품 판개 개수 : 37개
# 판매 이익 : 6290만원
# 순이익 : 1790만원
# ...
# ▶▶▶▶3일째◀◀◀◀
# 방문 고객 수 : 55명
# 제품 판개 개수 : 2개
# 판매 이익 : 340만원
# 순이익 : -4160만원
# ...
# ▶▶▶▶4일째◀◀◀◀
# 방문 고객 수 : 84명
# 제품 판개 개수 : 45개
# 판매 이익 : 7650만원
# 순이익 : 3150만원
# ...
# ▶▶▶▶5일째◀◀◀◀
# 방문 고객 수 : 1명
# 제품 판개 개수 : 11개
# 판매 이익 : 1870만원
# 순이익 : -2630만원
# ...
# ▶▶▶▶6일째◀◀◀◀
# 방문 고객 수 : 92명
# 제품 판개 개수 : 38개
# 판매 이익 : 6460만원
# 순이익 : 1960만원
# ...
# ▶▶▶▶7일째◀◀◀◀
# 방문 고객 수 : 81명
# 제품 판개 개수 : 31개
# 판매 이익 : 5270만원
# 순이익 : 770만원
# ...
# ▶▶▶▶8일째◀◀◀◀
# 방문 고객 수 : 7명
# 제품 판개 개수 : 29개
# 판매 이익 : 4930만원
# 순이익 : 430만원
# ...
# ▶▶▶▶9일째◀◀◀◀
# 방문 고객 수 : 8명
# 제품 판개 개수 : 33개
# 판매 이익 : 5610만원
# 순이익 : 1110만원
# ...
# ▶▶▶▶10일째◀◀◀◀
# 방문 고객 수 : 56명
# 제품 판개 개수 : 8개
# 판매 이익 : 1360만원
# 순이익 : -3140만원
# ...
# ▶▶▶▶11일째◀◀◀◀
# 방문 고객 수 : 40명
# 제품 판개 개수 : 35개
# 판매 이익 : 5950만원
# 순이익 : 1450만원
# ...
# ▶▶▶▶12일째◀◀◀◀
# ...

# %%
number = 34060
num1 = number // 10000
num2 = number - (num1 * 10000)
print(34060 % 10000)
print('{0}억 {1}만원'.format(num1, num2))
# Out:
# 4060
# 3억 4060만원
